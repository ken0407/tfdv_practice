# %% [markdown]
# # 準備

# %%
import pandas as pd
import tensorflow_data_validation as tfdv
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/titanic.csv')

# %% [markdown]
# ちなみに、infoで情報を出すとこんな感じ

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # TFDV の基本操作

# %% [markdown]
# ## 統計量の生成・可視化

# %% [markdown]
# まず`tfdv.generate_statistics_from_dataframe`を使用して各特徴量の統計量を作成していきます。戻り値はprotocol buffuersになっています。

# %%
stats = tfdv.generate_statistics_from_dataframe(df)
print(stats)
# Out:
# datasets {
#   num_examples: 891
#   features {
#     num_stats {
#       common_stats {
#         num_non_missing: 891
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 891
#       }
#       mean: 446.0
#       std_dev: 257.2093829289023
#       min: 1.0
#       median: 445.0
#       max: 891.0
#       histograms {
#         buckets {
#           low_value: 1.0
#           high_value: 90.0
#           sample_count: 90.21375
#         }
#         buckets {
#           low_value: 90.0
#           high_value: 179.0
#           sample_count: 87.98625
#         }
#         buckets {
#           low_value: 179.0
#           high_value: 268.0
#           sample_count: 90.21375
#         }
#         buckets {
#           low_value: 268.0
#           high_value: 357.0
#           sample_count: 87.09525000000001
#         }
#         buckets {
#           low_value: 357.0
#           high_value: 446.0
#           sample_count: 91.10475000000001
#         }
#         buckets {
#           low_value: 446.0
#           high_value: 535.0
#           sample_count: 87.09525000000001
#         }
#         buckets {
#           low_value: 535.0
#           high_value: 624.0
#           sample_count: 90.21375
#         }
#         buckets {
#           low_value: 624.0
#           high_value: 713.0
#           sample_count: 87.98625
#         }
#         buckets {
#           low_value: 713.0
#           high_value: 802.0
#           sample_count: 90.288
#         }
#         buckets {
#           low_value: 802.0
#           high_value: 891.0
#           sample_count: 88.80299999999998
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 1.0
#           high_value: 89.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 89.0
#           high_value: 179.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 179.0
#           high_value: 267.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 267.0
#           high_value: 357.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 357.0
#           high_value: 445.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 445.0
#           high_value: 535.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 535.0
#           high_value: 623.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 623.0
#           high_value: 713.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 713.0
#           high_value: 801.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 801.0
#           high_value: 891.0
#           sample_count: 89.1
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "PassengerId"
#     }
#   }
#   features {
#     num_stats {
#       common_stats {
#         num_non_missing: 891
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 891
#       }
#       mean: 0.3838383838383838
#       std_dev: 0.4863193178670999
#       num_zeros: 549
#       max: 1.0
#       histograms {
#         buckets {
#           high_value: 0.1
#           sample_count: 548.9451
#         }
#         buckets {
#           low_value: 0.1
#           high_value: 0.2
#           sample_count: 0.08910000000000001
#         }
#         buckets {
#           low_value: 0.2
#           high_value: 0.30000000000000004
#           sample_count: 0.08910000000000003
#         }
#         buckets {
#           low_value: 0.30000000000000004
#           high_value: 0.4
#           sample_count: 0.08909999999999998
#         }
#         buckets {
#           low_value: 0.4
#           high_value: 0.5
#           sample_count: 0.08909999999999998
#         }
#         buckets {
#           low_value: 0.5
#           high_value: 0.6000000000000001
#           sample_count: 0.08910000000000008
#         }
#         buckets {
#           low_value: 0.6000000000000001
#           high_value: 0.7000000000000001
#           sample_count: 0.08909999999999998
#         }
#         buckets {
#           low_value: 0.7000000000000001
#           high_value: 0.8
#           sample_count: 0.08909999999999998
#         }
#         buckets {
#           low_value: 0.8
#           high_value: 0.9
#           sample_count: 0.08909999999999998
#         }
#         buckets {
#           low_value: 0.9
#           high_value: 1.0
#           sample_count: 341.34209999999996
#         }
#       }
#       histograms {
#         buckets {
#           sample_count: 89.1
#         }
#         buckets {
#           sample_count: 89.1
#         }
#         buckets {
#           sample_count: 89.1
#         }
#         buckets {
#           sample_count: 89.1
#         }
#         buckets {
#           sample_count: 89.1
#         }
#         buckets {
#           sample_count: 89.1
#         }
#         buckets {
#           high_value: 1.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 89.1
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "Survived"
#     }
#   }
#   features {
#     num_stats {
#       common_stats {
#         num_non_missing: 891
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 891
#       }
#       mean: 2.308641975308642
#       std_dev: 0.8356019334795164
#       min: 1.0
#       median: 3.0
#       max: 3.0
#       histograms {
#         buckets {
#           low_value: 1.0
#           high_value: 1.2
#           sample_count: 215.80020000000002
#         }
#         buckets {
#           low_value: 1.2
#           high_value: 1.4
#           sample_count: 0.17819999999999997
#         }
#         buckets {
#           low_value: 1.4
#           high_value: 1.6
#           sample_count: 0.17820000000000016
#         }
#         buckets {
#           low_value: 1.6
#           high_value: 1.8
#           sample_count: 0.17819999999999997
#         }
#         buckets {
#           low_value: 1.8
#           high_value: 2.0
#           sample_count: 0.17819999999999997
#         }
#         buckets {
#           low_value: 2.0
#           high_value: 2.2
#           sample_count: 182.8332
#         }
#         buckets {
#           low_value: 2.2
#           high_value: 2.4000000000000004
#           sample_count: 0.17820000000000016
#         }
#         buckets {
#           low_value: 2.4000000000000004
#           high_value: 2.6
#           sample_count: 0.17819999999999978
#         }
#         buckets {
#           low_value: 2.6
#           high_value: 2.8
#           sample_count: 0.17819999999999978
#         }
#         buckets {
#           low_value: 2.8
#           high_value: 3.0
#           sample_count: 491.1192
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 2.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 2.0
#           high_value: 2.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 2.0
#           high_value: 3.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.0
#           sample_count: 89.1
#         }
#         buckets {
#           low_value: 3.0
#           high_value: 3.0
#           sample_count: 89.1
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "Pclass"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 891
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 89.1
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 891
#       }
#       unique: 891
#       top_values {
#         value: "van Melkebeke, Mr. Philemon"
#         frequency: 1.0
#       }
#       top_values {
#         value: "van Billiard, Mr. Austin Blyler"
#         frequency: 1.0
#       }
#       top_values {
#         value: "del Carlo, Mr. Sebastiano"
#         frequency: 1.0
#       }
#       top_values {
#         value: "de Pelsmaeker, Mr. Alfons"
#         frequency: 1.0
#       }
#       top_values {
#         value: "de Mulder, Mr. Theodore"
#         frequency: 1.0
#       }
#       top_values {
#         value: "de Messemaeker, Mrs. Guillaume Joseph (Emma)"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Zimmerman, Mr. Leo"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Zabour, Miss. Thamine"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Zabour, Miss. Hileni"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Yrois, Miss. Henriette (\"Mrs Harbeck\")"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Yousseff, Mr. Gerious"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Yousif, Mr. Wazli"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Youseff, Mr. Gerious"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Young, Miss. Marie Grice"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Yasbeck, Mrs. Antoni (Selini Alexander)"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Yasbeck, Mr. Antoni"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Wright, Mr. George"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Woolner, Mr. Hugh"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Wiseman, Mr. Phillippe"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Windelov, Mr. Einar"
#         frequency: 1.0
#       }
#       avg_length: 26.965208053588867
#       rank_histogram {
#         buckets {
#           label: "van Melkebeke, Mr. Philemon"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "van Billiard, Mr. Austin Blyler"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "del Carlo, Mr. Sebastiano"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 3
#           high_rank: 3
#           label: "de Pelsmaeker, Mr. Alfons"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 4
#           high_rank: 4
#           label: "de Mulder, Mr. Theodore"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 5
#           high_rank: 5
#           label: "de Messemaeker, Mrs. Guillaume Joseph (Emma)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 6
#           high_rank: 6
#           label: "Zimmerman, Mr. Leo"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7
#           high_rank: 7
#           label: "Zabour, Miss. Thamine"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 8
#           high_rank: 8
#           label: "Zabour, Miss. Hileni"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 9
#           high_rank: 9
#           label: "Yrois, Miss. Henriette (\"Mrs Harbeck\")"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 10
#           high_rank: 10
#           label: "Yousseff, Mr. Gerious"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 11
#           high_rank: 11
#           label: "Yousif, Mr. Wazli"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 12
#           high_rank: 12
#           label: "Youseff, Mr. Gerious"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 13
#           high_rank: 13
#           label: "Young, Miss. Marie Grice"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 14
#           high_rank: 14
#           label: "Yasbeck, Mrs. Antoni (Selini Alexander)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 15
#           high_rank: 15
#           label: "Yasbeck, Mr. Antoni"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 16
#           high_rank: 16
#           label: "Wright, Mr. George"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 17
#           high_rank: 17
#           label: "Woolner, Mr. Hugh"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 18
#           high_rank: 18
#           label: "Wiseman, Mr. Phillippe"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 19
#           high_rank: 19
#           label: "Windelov, Mr. Einar"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 20
#           high_rank: 20
#           label: "Williams-Lambert, Mr. Fletcher Fellows"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 21
#           high_rank: 21
#           label: "Williams, Mr. Leslie"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 22
#           high_rank: 22
#           label: "Williams, Mr. Howard Hugh \"Harry\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 23
#           high_rank: 23
#           label: "Williams, Mr. Charles Eugene"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 24
#           high_rank: 24
#           label: "Williams, Mr. Charles Duane"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 25
#           high_rank: 25
#           label: "Willey, Mr. Edward"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 26
#           high_rank: 26
#           label: "Wilhelms, Mr. Charles"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 27
#           high_rank: 27
#           label: "Wiklund, Mr. Jakob Alfred"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 28
#           high_rank: 28
#           label: "Widener, Mr. Harry Elkins"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 29
#           high_rank: 29
#           label: "Widegren, Mr. Carl/Charles Peter"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 30
#           high_rank: 30
#           label: "Wick, Mrs. George Dennick (Mary Hitchcock)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 31
#           high_rank: 31
#           label: "Wick, Miss. Mary Natalie"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 32
#           high_rank: 32
#           label: "White, Mr. Richard Frasar"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 33
#           high_rank: 33
#           label: "White, Mr. Percival Wayland"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 34
#           high_rank: 34
#           label: "Wheadon, Mr. Edward H"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 35
#           high_rank: 35
#           label: "West, Mrs. Edwy Arthur (Ada Mary Worth)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 36
#           high_rank: 36
#           label: "West, Mr. Edwy Arthur"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 37
#           high_rank: 37
#           label: "West, Miss. Constance Mirium"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 38
#           high_rank: 38
#           label: "Wells, Miss. Joan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 39
#           high_rank: 39
#           label: "Weisz, Mrs. Leopold (Mathilde Francoise Pede)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 40
#           high_rank: 40
#           label: "Weir, Col. John"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 41
#           high_rank: 41
#           label: "Webber, Mr. James"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 42
#           high_rank: 42
#           label: "Webber, Miss. Susan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 43
#           high_rank: 43
#           label: "Watt, Mrs. James (Elizabeth \"Bessie\" Inglis Milne)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 44
#           high_rank: 44
#           label: "Watson, Mr. Ennis Hastings"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 45
#           high_rank: 45
#           label: "Warren, Mrs. Frank Manley (Anna Sophia Atkinson)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 46
#           high_rank: 46
#           label: "Ward, Miss. Anna"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 47
#           high_rank: 47
#           label: "Walker, Mr. William Anderson"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 48
#           high_rank: 48
#           label: "Waelens, Mr. Achille"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 49
#           high_rank: 49
#           label: "Vovk, Mr. Janko"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 50
#           high_rank: 50
#           label: "Vestrom, Miss. Hulda Amanda Adolfina"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 51
#           high_rank: 51
#           label: "Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 52
#           high_rank: 52
#           label: "Vander Planke, Mr. Leo Edmondus"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 53
#           high_rank: 53
#           label: "Vander Planke, Miss. Augusta Maria"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 54
#           high_rank: 54
#           label: "Vander Cruyssen, Mr. Victor"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 55
#           high_rank: 55
#           label: "Vanden Steen, Mr. Leo Peter"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 56
#           high_rank: 56
#           label: "Vande Walle, Mr. Nestor Cyriel"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 57
#           high_rank: 57
#           label: "Vande Velde, Mr. Johannes Joseph"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 58
#           high_rank: 58
#           label: "Van der hoef, Mr. Wyckoff"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 59
#           high_rank: 59
#           label: "Van Impe, Mrs. Jean Baptiste (Rosalie Paula Govaert)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 60
#           high_rank: 60
#           label: "Van Impe, Mr. Jean Baptiste"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 61
#           high_rank: 61
#           label: "Van Impe, Miss. Catharina"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 62
#           high_rank: 62
#           label: "Uruchurtu, Don. Manuel E"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 63
#           high_rank: 63
#           label: "Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 64
#           high_rank: 64
#           label: "Turpin, Mr. William John Robert"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 65
#           high_rank: 65
#           label: "Turkula, Mrs. (Hedwig)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 66
#           high_rank: 66
#           label: "Turja, Miss. Anna Sofia"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 67
#           high_rank: 67
#           label: "Turcin, Mr. Stjepan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 68
#           high_rank: 68
#           label: "Troutt, Miss. Edwina Celia \"Winnie\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 69
#           high_rank: 69
#           label: "Trout, Mrs. William H (Jessie L)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 70
#           high_rank: 70
#           label: "Troupiansky, Mr. Moses Aaron"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 71
#           high_rank: 71
#           label: "Touma, Mrs. Darwis (Hanne Youssef Razi)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 72
#           high_rank: 72
#           label: "Toufik, Mr. Nakli"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 73
#           high_rank: 73
#           label: "Tornquist, Mr. William Henry"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 74
#           high_rank: 74
#           label: "Torber, Mr. Ernst William"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 75
#           high_rank: 75
#           label: "Toomey, Miss. Ellen"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 76
#           high_rank: 76
#           label: "Tomlin, Mr. Ernest Portage"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 77
#           high_rank: 77
#           label: "Todoroff, Mr. Lalio"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 78
#           high_rank: 78
#           label: "Tobin, Mr. Roger"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 79
#           high_rank: 79
#           label: "Tikkanen, Mr. Juho"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 80
#           high_rank: 80
#           label: "Thorneycroft, Mrs. Percival (Florence Kate White)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 81
#           high_rank: 81
#           label: "Thorneycroft, Mr. Percival"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 82
#           high_rank: 82
#           label: "Thorne, Mrs. Gertrude Maybelle"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 83
#           high_rank: 83
#           label: "Thomas, Master. Assad Alexander"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 84
#           high_rank: 84
#           label: "Theobald, Mr. Thomas Leonard"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 85
#           high_rank: 85
#           label: "Thayer, Mrs. John Borland (Marian Longstreth Morris)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 86
#           high_rank: 86
#           label: "Thayer, Mr. John Borland Jr"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 87
#           high_rank: 87
#           label: "Thayer, Mr. John Borland"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 88
#           high_rank: 88
#           label: "Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 89
#           high_rank: 89
#           label: "Taylor, Mr. Elmer Zebley"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 90
#           high_rank: 90
#           label: "Taussig, Mrs. Emil (Tillie Mandelbaum)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 91
#           high_rank: 91
#           label: "Taussig, Mr. Emil"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 92
#           high_rank: 92
#           label: "Taussig, Miss. Ruth"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 93
#           high_rank: 93
#           label: "Swift, Mrs. Frederick Joel (Margaret Welles Barron)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 94
#           high_rank: 94
#           label: "Svensson, Mr. Olof"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 95
#           high_rank: 95
#           label: "Svensson, Mr. Johan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 96
#           high_rank: 96
#           label: "Sutton, Mr. Frederick"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 97
#           high_rank: 97
#           label: "Sutehall, Mr. Henry Jr"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 98
#           high_rank: 98
#           label: "Sundman, Mr. Johan Julian"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 99
#           high_rank: 99
#           label: "Sunderland, Mr. Victor Francis"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 100
#           high_rank: 100
#           label: "Strom, Mrs. Wilhelm (Elna Matilda Persson)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 101
#           high_rank: 101
#           label: "Strom, Miss. Telma Matilda"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 102
#           high_rank: 102
#           label: "Stranden, Mr. Juho"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 103
#           high_rank: 103
#           label: "Strandberg, Miss. Ida Sofia"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 104
#           high_rank: 104
#           label: "Stoytcheff, Mr. Ilia"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 105
#           high_rank: 105
#           label: "Stone, Mrs. George Nelson (Martha Evelyn)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 106
#           high_rank: 106
#           label: "Stewart, Mr. Albert A"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 107
#           high_rank: 107
#           label: "Stephenson, Mrs. Walter Bertram (Martha Eustis)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 108
#           high_rank: 108
#           label: "Stead, Mr. William Thomas"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 109
#           high_rank: 109
#           label: "Stanley, Mr. Edward Roland"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 110
#           high_rank: 110
#           label: "Stanley, Miss. Amy Zillah Elsie"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 111
#           high_rank: 111
#           label: "Stankovic, Mr. Ivan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 112
#           high_rank: 112
#           label: "Staneff, Mr. Ivan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 113
#           high_rank: 113
#           label: "Stahelin-Maeglin, Dr. Max"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 114
#           high_rank: 114
#           label: "Spencer, Mrs. William Augustus (Marie Eugenie)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 115
#           high_rank: 115
#           label: "Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 116
#           high_rank: 116
#           label: "Somerton, Mr. Francis William"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 117
#           high_rank: 117
#           label: "Soholt, Mr. Peter Andreas Lauritz Andersen"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 118
#           high_rank: 118
#           label: "Sobey, Mr. Samuel James Hayden"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 119
#           high_rank: 119
#           label: "Smith, Mr. Thomas"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 120
#           high_rank: 120
#           label: "Smith, Mr. Richard William"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 121
#           high_rank: 121
#           label: "Smith, Mr. James Clinch"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 122
#           high_rank: 122
#           label: "Smith, Miss. Marion Elsie"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 123
#           high_rank: 123
#           label: "Smiljanic, Mr. Mile"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 124
#           high_rank: 124
#           label: "Smart, Mr. John Montgomery"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 125
#           high_rank: 125
#           label: "Sloper, Mr. William Thompson"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 126
#           high_rank: 126
#           label: "Slocovski, Mr. Selman Francis"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 127
#           high_rank: 127
#           label: "Slemen, Mr. Richard James"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 128
#           high_rank: 128
#           label: "Slayter, Miss. Hilda Mary"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 129
#           high_rank: 129
#           label: "Slabenoff, Mr. Petco"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 130
#           high_rank: 130
#           label: "Skoog, Mrs. William (Anna Bernhardina Karlsson)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 131
#           high_rank: 131
#           label: "Skoog, Mr. Wilhelm"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 132
#           high_rank: 132
#           label: "Skoog, Miss. Margit Elizabeth"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 133
#           high_rank: 133
#           label: "Skoog, Miss. Mabel"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 134
#           high_rank: 134
#           label: "Skoog, Master. Karl Thorsten"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 135
#           high_rank: 135
#           label: "Skoog, Master. Harald"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 136
#           high_rank: 136
#           label: "Sjostedt, Mr. Ernst Adolf"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 137
#           high_rank: 137
#           label: "Sjoblom, Miss. Anna Sofia"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 138
#           high_rank: 138
#           label: "Sivola, Mr. Antti Wilhelm"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 139
#           high_rank: 139
#           label: "Sivic, Mr. Husein"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 140
#           high_rank: 140
#           label: "Sirota, Mr. Maurice"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 141
#           high_rank: 141
#           label: "Sirayanian, Mr. Orsen"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 142
#           high_rank: 142
#           label: "Sinkkonen, Miss. Anna"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 143
#           high_rank: 143
#           label: "Simonius-Blumer, Col. Oberst Alfons"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 144
#           high_rank: 144
#           label: "Simmons, Mr. John"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 145
#           high_rank: 145
#           label: "Silvey, Mrs. William Baird (Alice Munger)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 146
#           high_rank: 146
#           label: "Silvey, Mr. William Baird"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 147
#           high_rank: 147
#           label: "Silverthorne, Mr. Spencer Victor"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 148
#           high_rank: 148
#           label: "Silven, Miss. Lyyli Karoliina"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 149
#           high_rank: 149
#           label: "Shutes, Miss. Elizabeth W"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 150
#           high_rank: 150
#           label: "Shorney, Mr. Charles Joseph"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 151
#           high_rank: 151
#           label: "Shelley, Mrs. William (Imanita Parrish Hall)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 152
#           high_rank: 152
#           label: "Shellard, Mr. Frederick William"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 153
#           high_rank: 153
#           label: "Sheerlinck, Mr. Jan Baptist"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 154
#           high_rank: 154
#           label: "Sharp, Mr. Percival James R"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 155
#           high_rank: 155
#           label: "Seward, Mr. Frederic Kimber"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 156
#           high_rank: 156
#           label: "Serepeca, Miss. Augusta"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 157
#           high_rank: 157
#           label: "Sedgwick, Mr. Charles Frederick Waddington"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 158
#           high_rank: 158
#           label: "Sdycoff, Mr. Todor"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 159
#           high_rank: 159
#           label: "Scanlan, Mr. James"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 160
#           high_rank: 160
#           label: "Sawyer, Mr. Frederick Charles"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 161
#           high_rank: 161
#           label: "Saundercock, Mr. William Henry"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 162
#           high_rank: 162
#           label: "Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengtsson)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 163
#           high_rank: 163
#           label: "Sandstrom, Miss. Marguerite Rut"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 164
#           high_rank: 164
#           label: "Samaan, Mr. Youssef"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 165
#           high_rank: 165
#           label: "Salonen, Mr. Johan Werner"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 166
#           high_rank: 166
#           label: "Salkjelsvik, Miss. Anna Kristine"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 167
#           high_rank: 167
#           label: "Sagesser, Mlle. Emma"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 168
#           high_rank: 168
#           label: "Sage, Mr. George John Jr"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 169
#           high_rank: 169
#           label: "Sage, Mr. Frederick"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 170
#           high_rank: 170
#           label: "Sage, Mr. Douglas Bullen"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 171
#           high_rank: 171
#           label: "Sage, Miss. Stella Anna"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 172
#           high_rank: 172
#           label: "Sage, Miss. Dorothy Edith \"Dolly\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 173
#           high_rank: 173
#           label: "Sage, Miss. Constance Gladys"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 174
#           high_rank: 174
#           label: "Sage, Master. Thomas Henry"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 175
#           high_rank: 175
#           label: "Sadlier, Mr. Matthew"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 176
#           high_rank: 176
#           label: "Saalfeld, Mr. Adolphe"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 177
#           high_rank: 177
#           label: "Saad, Mr. Khalil"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 178
#           high_rank: 178
#           label: "Saad, Mr. Amin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 179
#           high_rank: 179
#           label: "Ryerson, Miss. Susan Parker \"Suzette\""
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 180
#           high_rank: 180
#           label: "Ryerson, Miss. Emily Borie"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 181
#           high_rank: 181
#           label: "Ryan, Mr. Patrick"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 182
#           high_rank: 182
#           label: "Rush, Mr. Alfred George John"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 183
#           high_rank: 183
#           label: "Rugg, Miss. Emily"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 184
#           high_rank: 184
#           label: "Rouse, Mr. Richard Henry"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 185
#           high_rank: 185
#           label: "Rothschild, Mrs. Martin (Elizabeth L. Barrett)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 186
#           high_rank: 186
#           label: "Rothes, the Countess. of (Lucy Noel Martha Dyer-Edwards)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 187
#           high_rank: 187
#           label: "Ross, Mr. John Hugo"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 188
#           high_rank: 188
#           label: "Rosblom, Mrs. Viktor (Helena Wilhelmina)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 189
#           high_rank: 189
#           label: "Rosblom, Mr. Viktor Richard"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 190
#           high_rank: 190
#           label: "Rood, Mr. Hugh Roscoe"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 191
#           high_rank: 191
#           label: "Rommetvedt, Mr. Knud Paust"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 192
#           high_rank: 192
#           label: "Romaine, Mr. Charles Hallace (\"Mr C Rolmane\")"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 193
#           high_rank: 193
#           label: "Rogers, Mr. William John"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 194
#           high_rank: 194
#           label: "Roebling, Mr. Washington Augustus II"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 195
#           high_rank: 195
#           label: "Robins, Mrs. Alexander A (Grace Charity Laury)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 196
#           high_rank: 196
#           label: "Robert, Mrs. Edward Scott (Elisabeth Walton McMillan)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 197
#           high_rank: 197
#           label: "Robbins, Mr. Victor"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 198
#           high_rank: 198
#           label: "Risien, Mr. Samuel Beard"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 199
#           high_rank: 199
#           label: "Rintamaki, Mr. Matti"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 200
#           high_rank: 200
#           label: "Ringhini, Mr. Sante"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 201
#           high_rank: 201
#           label: "Ridsdale, Miss. Lucy"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 202
#           high_rank: 202
#           label: "Richards, Mrs. Sidney (Emily Hocking)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 203
#           high_rank: 203
#           label: "Richards, Master. William Rowe"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 204
#           high_rank: 204
#           label: "Richards, Master. George Sibley"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 205
#           high_rank: 205
#           label: "Richard, Mr. Emile"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 206
#           high_rank: 206
#           label: "Rice, Mrs. William (Margaret Norton)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 207
#           high_rank: 207
#           label: "Rice, Master. George Hugh"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 208
#           high_rank: 208
#           label: "Rice, Master. Eugene"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 209
#           high_rank: 209
#           label: "Rice, Master. Eric"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 210
#           high_rank: 210
#           label: "Rice, Master. Arthur"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 211
#           high_rank: 211
#           label: "Reynaldo, Ms. Encarnacion"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 212
#           high_rank: 212
#           label: "Reuchlin, Jonkheer. John George"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 213
#           high_rank: 213
#           label: "Renouf, Mrs. Peter Henry (Lillian Jefferys)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 214
#           high_rank: 214
#           label: "Renouf, Mr. Peter Henry"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 215
#           high_rank: 215
#           label: "Rekic, Mr. Tido"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 216
#           high_rank: 216
#           label: "Reeves, Mr. David"
#           sample_count: 1.0
#         }
#         buckets {
# ...
#           label: "B51 B53 B55"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 39
#           high_rank: 39
#           label: "B5"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 40
#           high_rank: 40
#           label: "B49"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 41
#           high_rank: 41
#           label: "B35"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 42
#           high_rank: 42
#           label: "B28"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 43
#           high_rank: 43
#           label: "B22"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 44
#           high_rank: 44
#           label: "B20"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 45
#           high_rank: 45
#           label: "B18"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 46
#           high_rank: 46
#           label: "T"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 47
#           high_rank: 47
#           label: "F38"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 48
#           high_rank: 48
#           label: "F G63"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 49
#           high_rank: 49
#           label: "F E69"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 50
#           high_rank: 50
#           label: "E77"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 51
#           high_rank: 51
#           label: "E68"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 52
#           high_rank: 52
#           label: "E63"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 53
#           high_rank: 53
#           label: "E58"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 54
#           high_rank: 54
#           label: "E50"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 55
#           high_rank: 55
#           label: "E49"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 56
#           high_rank: 56
#           label: "E46"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 57
#           high_rank: 57
#           label: "E40"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 58
#           high_rank: 58
#           label: "E38"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 59
#           high_rank: 59
#           label: "E36"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 60
#           high_rank: 60
#           label: "E34"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 61
#           high_rank: 61
#           label: "E31"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 62
#           high_rank: 62
#           label: "E17"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 63
#           high_rank: 63
#           label: "E12"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 64
#           high_rank: 64
#           label: "E10"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 65
#           high_rank: 65
#           label: "D9"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 66
#           high_rank: 66
#           label: "D7"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 67
#           high_rank: 67
#           label: "D6"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 68
#           high_rank: 68
#           label: "D56"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 69
#           high_rank: 69
#           label: "D50"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 70
#           high_rank: 70
#           label: "D49"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 71
#           high_rank: 71
#           label: "D48"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 72
#           high_rank: 72
#           label: "D47"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 73
#           high_rank: 73
#           label: "D46"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 74
#           high_rank: 74
#           label: "D45"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 75
#           high_rank: 75
#           label: "D37"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 76
#           high_rank: 76
#           label: "D30"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 77
#           high_rank: 77
#           label: "D28"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 78
#           high_rank: 78
#           label: "D21"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 79
#           high_rank: 79
#           label: "D19"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 80
#           high_rank: 80
#           label: "D15"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 81
#           high_rank: 81
#           label: "D11"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 82
#           high_rank: 82
#           label: "D10 D12"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 83
#           high_rank: 83
#           label: "C99"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 84
#           high_rank: 84
#           label: "C95"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 85
#           high_rank: 85
#           label: "C91"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 86
#           high_rank: 86
#           label: "C90"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 87
#           high_rank: 87
#           label: "C87"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 88
#           high_rank: 88
#           label: "C86"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 89
#           high_rank: 89
#           label: "C85"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 90
#           high_rank: 90
#           label: "C82"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 91
#           high_rank: 91
#           label: "C70"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 92
#           high_rank: 92
#           label: "C7"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 93
#           high_rank: 93
#           label: "C62 C64"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 94
#           high_rank: 94
#           label: "C54"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 95
#           high_rank: 95
#           label: "C50"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 96
#           high_rank: 96
#           label: "C49"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 97
#           high_rank: 97
#           label: "C47"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 98
#           high_rank: 98
#           label: "C46"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 99
#           high_rank: 99
#           label: "C45"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 100
#           high_rank: 100
#           label: "C32"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 101
#           high_rank: 101
#           label: "C30"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 102
#           high_rank: 102
#           label: "C148"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 103
#           high_rank: 103
#           label: "C128"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 104
#           high_rank: 104
#           label: "C118"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 105
#           high_rank: 105
#           label: "C111"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 106
#           high_rank: 106
#           label: "C110"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 107
#           high_rank: 107
#           label: "C106"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 108
#           high_rank: 108
#           label: "C104"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 109
#           high_rank: 109
#           label: "C103"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 110
#           high_rank: 110
#           label: "C101"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 111
#           high_rank: 111
#           label: "B94"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 112
#           high_rank: 112
#           label: "B86"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 113
#           high_rank: 113
#           label: "B82 B84"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 114
#           high_rank: 114
#           label: "B80"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 115
#           high_rank: 115
#           label: "B79"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 116
#           high_rank: 116
#           label: "B78"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 117
#           high_rank: 117
#           label: "B73"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 118
#           high_rank: 118
#           label: "B71"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 119
#           high_rank: 119
#           label: "B69"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 120
#           high_rank: 120
#           label: "B50"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 121
#           high_rank: 121
#           label: "B42"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 122
#           high_rank: 122
#           label: "B41"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 123
#           high_rank: 123
#           label: "B4"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 124
#           high_rank: 124
#           label: "B39"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 125
#           high_rank: 125
#           label: "B38"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 126
#           high_rank: 126
#           label: "B37"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 127
#           high_rank: 127
#           label: "B30"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 128
#           high_rank: 128
#           label: "B3"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 129
#           high_rank: 129
#           label: "B19"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 130
#           high_rank: 130
#           label: "B102"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 131
#           high_rank: 131
#           label: "B101"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 132
#           high_rank: 132
#           label: "A7"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 133
#           high_rank: 133
#           label: "A6"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 134
#           high_rank: 134
#           label: "A5"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 135
#           high_rank: 135
#           label: "A36"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 136
#           high_rank: 136
#           label: "A34"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 137
#           high_rank: 137
#           label: "A32"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 138
#           high_rank: 138
#           label: "A31"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 139
#           high_rank: 139
#           label: "A26"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 140
#           high_rank: 140
#           label: "A24"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 141
#           high_rank: 141
#           label: "A23"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 142
#           high_rank: 142
#           label: "A20"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 143
#           high_rank: 143
#           label: "A19"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 144
#           high_rank: 144
#           label: "A16"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 145
#           high_rank: 145
#           label: "A14"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 146
#           high_rank: 146
#           label: "A10"
#           sample_count: 1.0
#         }
#       }
#     }
#     path {
#       step: "Cabin"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 889
#         num_missing: 2
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 88.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 88.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 88.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 88.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 88.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 88.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 88.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 88.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 88.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 88.9
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 889
#       }
#       unique: 3
#       top_values {
#         value: "S"
#         frequency: 644.0
#       }
#       top_values {
#         value: "C"
#         frequency: 168.0
#       }
#       top_values {
#         value: "Q"
#         frequency: 77.0
#       }
#       avg_length: 1.0
#       rank_histogram {
#         buckets {
#           label: "S"
#           sample_count: 644.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "C"
#           sample_count: 168.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "Q"
#           sample_count: 77.0
#         }
#       }
#     }
#     path {
#       step: "Embarked"
#     }
#   }
# }

# %% [markdown]
# `visualize_statistics`を使ってデータの統計量を可視化します。

# %%
tfdv.visualize_statistics(stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ちなみに、csvあるいはtfrecordのファイルを直接読み込んで統計量を作り、可視化することもできる。

# %%
# tfrecordの場合は generate_statistics_from_csv -> generate_statistics_from_tfrecord
tfdv.visualize_statistics(tfdv.generate_statistics_from_csv('data/titanic.csv', delimiter=','))
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# WARNING:tensorflow:From /Users/ishiikentarou/Documents/tfdv_practice/venv/lib/python3.7/site-packages/tensorflow_data_validation/utils/stats_util.py:229: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /Users/ishiikentarou/Documents/tfdv_practice/venv/lib/python3.7/site-packages/tensorflow_data_validation/utils/stats_util.py:229: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ## スキーマの生成・可視化

# %% [markdown]
# tfdvではデータからスキーマを自動生成することができ、かつそのスキーマを可視化することができます。

# %%
stats = tfdv.generate_statistics_from_dataframe(df)
schema = tfdv.infer_schema(stats)
schema
# Out:
# feature {
#   name: "PassengerId"
#   type: INT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "Survived"
#   type: INT
#   bool_domain {
#   }
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "Pclass"
#   type: INT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "Name"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "Sex"
#   type: BYTES
#   domain: "Sex"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "Age"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: FLOAT
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "SibSp"
#   type: INT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "Parch"
#   type: INT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "Ticket"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "Fare"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "Cabin"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   presence {
#     min_count: 1
#   }
# }
# feature {
#   name: "Embarked"
#   value_count {
#     min: 1
#     max: 1
#   }
#   type: BYTES
#   domain: "Embarked"
#   presence {
#     min_count: 1
#   }
# }
# string_domain {
#   name: "Sex"
#   value: "female"
#   value: "male"
# }
# string_domain {
#   name: "Embarked"
#   value: "C"
#   value: "Q"
#   value: "S"
# }

# %%
tfdv.display_schema(schema)
# Out:
#                  Type  Presence Valency      Domain
# Feature name
# 'PassengerId'     INT  required                   -
# 'Survived'        INT  required                   -
# 'Pclass'          INT  required                   -
# 'Name'          BYTES  required                   -
# 'Sex'          STRING  required               'Sex'
# 'Age'           FLOAT  optional  single           -
# 'SibSp'           INT  required                   -
# 'Parch'           INT  required                   -
# 'Ticket'        BYTES  required                   -
# 'Fare'          FLOAT  required                   -
# 'Cabin'         BYTES  optional  single           -
# 'Embarked'     STRING  optional  single  'Embarked'
#                       Values
# Domain
# 'Sex'       'female', 'male'
# 'Embarked'  'C', 'Q', 'S'

# %% [markdown]
# # 異常の検知

# %% [markdown]
# ## 準備

# %%
train = df.iloc[:600]
valid = df.iloc[600:].reset_index(drop=True)

print(f'train: {train.shape}')
display(train.head())
print(f'valid: {valid.shape}')
display(valid.head())
# Out:
# train: (600, 12)
#    PassengerId  Survived  Pclass  \
# 0  1            0         3
# 1  2            1         1
# 2  3            1         3
# 3  4            1         1
# 4  5            0         3
#
#                                                   Name     Sex   Age  SibSp  \
# 0  Braund, Mr. Owen Harris                              male    22.0  1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0  1
# 2  Heikkinen, Miss. Laina                               female  26.0  0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)         female  35.0  1
# 4  Allen, Mr. William Henry                             male    35.0  0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0  0      A/5 21171         7.2500   NaN   S
# 1  0      PC 17599          71.2833  C85   C
# 2  0      STON/O2. 3101282  7.9250   NaN   S
# 3  0      113803            53.1000  C123  S
# 4  0      373450            8.0500   NaN   S
# valid: (291, 12)
#    PassengerId  Survived  Pclass  \
# 0  601          1         2
# 1  602          0         3
# 2  603          0         1
# 3  604          0         3
# 4  605          1         1
#
#                                                   Name     Sex   Age  SibSp  \
# 0  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Christy)  female  24.0  2
# 1  Slabenoff, Mr. Petco                                 male   NaN    0
# 2  Harrington, Mr. Charles H                            male   NaN    0
# 3  Torber, Mr. Ernst William                            male    44.0  0
# 4  Homer, Mr. Harry ("Mr E Haven")                      male    35.0  0
#
#    Parch  Ticket     Fare Cabin Embarked
# 0  1      243847  27.0000  NaN   S
# 1  0      349214  7.8958   NaN   S
# 2  0      113796  42.4000  NaN   S
# 3  0      364511  8.0500   NaN   S
# 4  0      111426  26.5500  NaN   C

# %% [markdown]
# ## スキーマ異常の検知

# %%
schema = tfdv.infer_schema(tfdv.generate_statistics_from_dataframe(train))

# %% [markdown]
# ### カラムが欠けていた場合

# %%
lack_col_valid = valid.copy().drop('Pclass', axis=1)
anomaly = tfdv.validate_statistics(tfdv.generate_statistics_from_dataframe(lack_col_valid),
                                     schema,
                                    )
tfdv.display_anomalies(anomaly)
# Out:
#              Anomaly short description      Anomaly long description
# Feature name
# 'Pclass'      Column dropped            Column is completely missing

# %% [markdown]
# ### 未知の値が入っていた場合

# %%
new_val_in_sex_valid = valid.copy()
new_val_in_sex_valid.loc[0, 'Sex'] = 'dog'
anomaly = tfdv.validate_statistics(tfdv.generate_statistics_from_dataframe(new_val_in_sex_valid),
                                   schema,
                                  )
tfdv.display_anomalies(anomaly)
# Out:
#              Anomaly short description  \
# Feature name
# 'Sex'         Unexpected string values
#
#                                                   Anomaly long description
# Feature name
# 'Sex'         Examples contain values missing from the schema: dog (<1%).

# %% [markdown]
# ### 異常がない場合

# %%
anomaly = tfdv.validate_statistics(tfdv.generate_statistics_from_dataframe(train),
                                   schema,
                                  )
tfdv.display_anomalies(anomaly)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>

# %%
tfdv.display_schema(schema)
# Out:
#                  Type  Presence Valency      Domain
# Feature name
# 'PassengerId'  INT     required          -
# 'Survived'     INT     required          -
# 'Pclass'       INT     required          -
# 'Name'         BYTES   required          -
# 'Sex'          STRING  required          'Sex'
# 'Age'          FLOAT   optional  single  -
# 'SibSp'        INT     required          -
# 'Parch'        INT     required          -
# 'Ticket'       BYTES   required          -
# 'Fare'         FLOAT   required          -
# 'Cabin'        BYTES   optional  single  -
# 'Embarked'     STRING  optional  single  'Embarked'
#                       Values
# Domain
# 'Sex'       'female', 'male'
# 'Embarked'  'C', 'Q', 'S'

# %% [markdown]
# ## 分布の異常検知

# %%
error_distribution_valid = valid.copy()
error_distribution_valid['Age'] = error_distribution_valid['Age'] * 2

tfdv.visualize_statistics(lhs_statistics=tfdv.generate_statistics_from_dataframe(train),
                          rhs_statistics=tfdv.generate_statistics_from_dataframe(error_distribution_valid),
                          lhs_name='TRAIN_DATASET',
                          rhs_name='VALID_DATASET'
)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
